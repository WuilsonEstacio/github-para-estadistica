# %% [markdown]
# <a href="https://colab.research.google.com/github/WuilsonEstacio/github-para-estadistica/blob/main/Distribuciones_de_probabilidad_con_Python_Distribuciones_Discretas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Distribuciones
# # Distribuciones Discretas
# Las distribuciones discretas son aquellas en las que la variable puede tomar solo algunos valores determinados. Los principales exponentes de este grupo son las siguientes
# https://relopezbriega.github.io/blog/2016/06/29/distribuciones-de-probabilidad-con-python/

# %%
import numpy as np
from scipy import stats
import matplotlib
import matplotlib.pyplot as plt
import importlib
from scipy.stats import skew, kurtosis, chi2
import pandas as pd
from scipy import stats # importando scipy.stats
import seaborn as sns # importando seaborn

# importanto la api de statsmodels
import statsmodels.formula.api as smf
import statsmodels.api as sm

from numpy import random

# %% [markdown]
# # Distribución Poisson
# La Distribución Poisson esta dada por la formula:
#
# p(r;μ)=(μ^r e^-μ)/r!

# %% [markdown]
# # *Ejemplo-1*
#  1) El número promedio de partículas radioactivas que pasan a través de un contador durante un milisegundo en un experimento de laboratorio es 4. ¿Cuál es la probabilidad de que entren 6 partículas al contador en un milisegundo determinado?.
#
#  Estadistica y Probabilidad fundamental

# %%
mu =  4 # parametro de forma 
poisson = stats.poisson(mu) # Distribución
x = np.arange(poisson.ppf(0.01), poisson.ppf(0.99))
fmp = poisson.pmf(x) # Función de Masa de Probabilidad
r_values = list(range(mu + 4)) 

# printing the table 
print("r\tp(r)") 
for i in range(mu + 4):
  print(str(r_values[i])+ "\t" + str(fmp[i]))
# Out:
# r	p(r)
# 0	0.01831563888873418
# 1	0.07326255555493673
# 2	0.14652511110987343
# 3	0.19536681481316454
# 4	0.19536681481316454
# 5	0.1562934518505317
# 6	0.10419563456702102
# 7	0.0595403626097263

# %%
# Graficando Poisson
mu =  4 # parametro de forma 
poisson = stats.poisson(mu) # Distribución
x = np.arange(poisson.ppf(0.01), poisson.ppf(0.99))
fmp = poisson.pmf(x) # Función de Masa de Probabilidad

#para graficar
plt.plot(x, fmp, '--')
plt.vlines(x, 0, fmp, colors='b', lw=5, alpha=0.5)
plt.title('Distribución Poisson')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %%
# histograma
aleatorios = poisson.rvs(1000)  # genera aleatorios
cuenta, cajas, ignorar = plt.hist(aleatorios, 40)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma Poisson')
plt.show()

# %% [markdown]
# # Distribución Binomial
# https://relopezbriega.github.io/blog/2016/06/29/distribuciones-de-probabilidad-con-python/

# %%
# Graficando Binomial
N, p = 30, 0.4 # parametros de forma 
binomial = stats.binom(N, p) # Distribución
x = np.arange(binomial.ppf(0.01), binomial.ppf(0.99))
fmp = binomial.pmf(x) # Función de Masa de Probabilidad
plt.plot(x, fmp, '--')
plt.vlines(x, 0, fmp, colors='b', lw=5, alpha=0.5)
plt.title('Distribución Binomial')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %%
# histograma
aleatorios = binomial.rvs(1000)  # genera aleatorios
cuenta, cajas, ignorar = plt.hist(aleatorios, 40)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma Binomial')
plt.show()

# %% [markdown]
# # Distribución Geométrica

# %% [markdown]
# En una distribución hipergeométrica el resultado de una observación afecta el resultado de las obseravciones
# previas.
# La Distribución Geométrica esta dada por la formula:
#
# p(r;p)=p(1−p)^r−1
#
# La Distribución Geométrica expresa la probabilidad de tener que esperar exactamente r pruebas hasta encontrar el primer éxito si la probabilidad de éxito en una sola prueba es p. Por ejemplo, en un proceso de selección, podría definir el número de entrevistas que deberíamos realizar antes de encontrar al primer candidato aceptable.

# %%
# Graficando Geométrica
p =  0.3 # parametro de forma p(probabilidad)
geometrica = stats.geom(p) # Distribución
x = np.arange(geometrica.ppf(0.01), geometrica.ppf(0.99))
fmp = geometrica.pmf(x) # Función de Masa de Probabilidad
plt.plot(x, fmp, '--')
plt.vlines(x, 0, fmp, colors='b', lw=5, alpha=0.5) # vlines(x, ymin, ymax, colors='k', linestyles='solid', label='', *, data=None, **kwargs):
plt.title('Distribución Geométrica')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %%
# histograma
aleatorios = geometrica.rvs(1000)  # genera aleatorios
cuenta, cajas, ignorar = plt.hist(aleatorios, 40)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma Geométrica')
plt.show()

# %% [markdown]
# # Distribución Hipergeométrica
#
# Tanto la distribución binomial como la distribución hipergeométrica persiguen un mismo
# objetivo: el número de éxitos en una muestra que contiene observaciones. Lo que establece una
# diferencia entre estas dos distribuciones de probabilidad discreta es la forma en que se obtiene la
# información. Para el caso de la distribución binomial la información de la muestra se toma con reposición
# de una muestra finita, o sin reposición de una población infinita. Para el modelo hipergeométrico la
# información de la muestra se toma sin reposición de una población finita. Por lo tanto, la probabilidad de
# éxito, ,es constante a lo largo de todas las observ  aciones de un experimento binomial, en cambio, en una
# distribución hipergeométrica el resultado de una observación afecta el resultado de las obseravciones
# previas.
#  En general, el interés que se tiene es en la probabilidad de seleccionar éxitos de los posibles %
# resultados o artículos también considerados éxitos y fracasos de los posibles resultados o c% 5c
# artículos también considerados fracasos, cuando una muestra aleatoria de tamaño se selecciona de  5
# resultados o artículos totales. Esto se conoce como un experimento hipergeométrico.

# %% [markdown]
# # Ejemplos
#  1) Un comité compuesto por cinco personas se selecciona aleatoriamente de un grupo formado por tres químicos y cinco físicos. Encuentre la distribución de probabilidad para el número de químicos en el comité.
#
# X= v.a que indica el número de químicos
#
# X={0,1,2,3}
#
# N=8,    n=5,   k=3,     N-k =5
#
# Estadistica y Probabilidad fundamental

# %%
# Graficando Hipergeométrica
k, n, N = 3, 5, 8 # k posibles resultados donde se puede tener exito, n observaciones  N resultados totales o muestra para escoger 
hipergeometrica = stats.hypergeom(N, n, k) # Distribución
x = np.arange(0, n+1)
fmp = hipergeometrica.pmf(x) # Función de Masa de Probabilidad
r_values = list(range(n + 1)) 

print("r\tp(r)") 
for i in range(n + 1):
  print(str(r_values[i]) + "\t" + str(fmp[i]))
# Out:
# r	p(r)
# 0	0.01785714285714288
# 1	0.26785714285714335
# 2	0.5357142857142863
# 3	0.17857142857142877
# 4	0.0
# 5	0.0

# %%
# Graficando Hipergeométrica
k, n, N = 3, 5, 8 # parametros de forma 
hipergeometrica = stats.hypergeom(N, n, k) # Distribución
x = np.arange(0, n+1)
fmp = hipergeometrica.pmf(x) # Función de Masa de Probabilidad

plt.plot(x, fmp, '--')
plt.vlines(x, 0, fmp, colors='b', lw=5, alpha=0.5)
plt.title('Distribución Hipergeométrica')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %%
aleatorios = hipergeometrica.rvs(1000)  # genera aleatorios
cuenta, cajas, ignorar = plt.hist(aleatorios, 20)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma Hipergeométrica')
plt.show()

# %% [markdown]
# # Ejemplo B
#
# 2) Entre 16 postulantes para un trabajo, 10 tenían un grado universitario. Si tres de los postulantes son elegidos al azar para una entrevista. ¿Cuál es la probabilidad de que:
#
#  a) ninguno tenga grado universitario?.
#
#  b) exactamente uno tenga grado universitario?.
#
#  c) dos tengan grado universitario?.
#
#  d) los tres tengan grado universitario?

# %%
# mostrando datos de probabilidad de Hipergeométrica
k, n, N = 10, 3, 16 # k posibles resultados donde se puede tener exito, n observaciones (tamaño muestra), N resultados totales
hipergeometrica = stats.hypergeom(N, n, k) # Distribución
x = np.arange(0, n+1)
fmp = hipergeometrica.pmf(x) # Función de Masa de Probabilidad
r_values = list(range(n + 1)) 

print("r\tp(r)") 
for i in range(n + 1):
  print(str(r_values[i]) + "\t" + str(fmp[i]))
# Out:
# r	p(r)
# 0	0.03571428571428573
# 1	0.2678571428571426
# 2	0.4821428571428574
# 3	0.2142857142857143

# %% [markdown]
# La probabilidad de que ninguno tenga grado universitario es de 0.03571428571428573
#
# La probabilidad de que uno tenga grado universitario es de 0.2678571428571426
#
# La probabilidad de que dos tengan grado universitario es de 0.4821428571428574
#
# La probabilidad de que los tres tengan grado universitario es de 0.2142857142857143

# %%
# Graficando Hipergeométrica
k, n, N = 10, 3, 16 # parametros de forma 
hipergeometrica = stats.hypergeom(N, n, k) # Distribución
x = np.arange(0, n+1)
fmp = hipergeometrica.pmf(x) # Función de Masa de Probabilidad

plt.plot(x, fmp, '--')
plt.vlines(x, 0, fmp, colors='b', lw=5, alpha=0.5)
plt.title('Distribución Hipergeométrica')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %%
# histograma Hipergeométrica
aleatorios = hipergeometrica.rvs(1000)  # genera aleatorios
cuenta, cajas, ignorar = plt.hist(aleatorios, 20)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma Hipergeométrica')
plt.show()

# %% [markdown]
# # Distribución de Bernoulli

# %% [markdown]
# En dónde el parámetro p es la probabilidad de éxito en un solo ensayo, la probabilidad de fracaso por lo tanto va a ser 1−p (muchas veces expresada como q). Tanto p como q van a estar limitados al intervalo de cero a uno. La Distribución de Bernoulli describe un experimento probabilístico en donde el ensayo tiene dos posibles resultados, éxito o fracaso. Desde esta distribución se pueden deducir varias Funciones de Densidad de Probabilidad de otras distribuciones que se basen en una serie de ensayos independientes.

# %% [markdown]
# # Ejemplo
#
# Calcular la función de distribución del corredor en una competición de 10 corredores.
#
# p=1/10=0.1,  q=1-p= 0.9

# %%
p =  0.1 # probabilidad de exito 
bernoulli = stats.bernoulli(p)
x = np.arange(0, 10)
fmp = bernoulli.pmf(x) # Función de Masa de Probabilidad
r_values = list(range(10)) 

print("r\tp(r)") 
for i in range(n + 1):
  print(str(r_values[i]) + "\t" + str(fmp[i]))
# Out:
# r	p(r)
# 0	0.9
# 1	0.10000000000000002
# 2	0.0
# 3	0.0

# %% [markdown]
# esto quiere decir que existe gran probabilidad de que pierda la carrera

# %%
# Graficando Bernoulli
p =  0.1 # probabilidad de exito 
bernoulli = stats.bernoulli(p)
x = np.arange(-1, 10)
fmp = bernoulli.pmf(x) # Función de Masa de Probabilidad
fig, ax = plt.subplots()
ax.plot(x, fmp, 'bo')
ax.vlines(x, 0, fmp, colors='b', lw=5, alpha=0.5)
ax.set_yticks([0., 0.2, 0.4, 0.6, 0.8, 0.99])
plt.title('Distribución Bernoulli')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %%
# histograma Bernoulli
aleatorios = bernoulli.rvs(1000)  # genera aleatorios
cuenta, cajas, ignorar = plt.hist(aleatorios, 20)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma Bernoulli')
plt.show()

# %% [markdown]
# # Distribuciones continuas
#
# Distribuciones de probabilidad con Python-Distribuciones Continuas.ipynb
#
# https://relopezbriega.github.io/blog/2016/06/29/distribuciones-de-probabilidad-con-python/#Distribuciones-continuas
